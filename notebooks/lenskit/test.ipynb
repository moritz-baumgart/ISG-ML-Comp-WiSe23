# %%
import joblib
import pandas as pd

x = joblib.load('time_window_result.joblib')

pd.DataFrame(x, columns=['start', 'stop', 'model', 'rmse'])
# Out:
#            start           stop  \
# 0  1230264009677  1293336009677
# 1  1277568009677  1340640009677
# 2  1324872009677  1387944009677
# 3  1372176009677  1435248009677
# 4  1419480009677  1482552009677
# 5  1466784009677  1529856009677
# 6  1514088009677  1577160009677
# 7  1561392009677  1624464009677
# 8  1608696009677  1671768009677
#
#                                            model      rmse
# 0  als.BiasedMF(features=50, regularization=0.1)  0.100000
# 1  als.BiasedMF(features=50, regularization=0.1)  0.101058
# 2  als.BiasedMF(features=50, regularization=0.1)  0.087947
# 3  als.BiasedMF(features=50, regularization=0.1)  0.100155
# 4  als.BiasedMF(features=50, regularization=0.1)  0.108244
# 5  als.BiasedMF(features=50, regularization=0.1)  0.125730
# 6  als.BiasedMF(features=50, regularization=0.1)  0.136089
# 7  als.BiasedMF(features=50, regularization=0.1)  0.123907
# 8  als.BiasedMF(features=50, regularization=0.1)  0.105164
